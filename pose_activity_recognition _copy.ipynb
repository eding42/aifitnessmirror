# %% [markdown]
# # AI Fitness Mirror - Pose-Based Activity Recognition
#
# This notebook implements a complete pipeline for:
# 1. **Pose Estimation**: Extract skeletal keypoints from images/videos using MoveNet Lightning
# 2. **Activity Classification**: Train a lightweight DNN to classify activities (pushups, situps, etc.)
# 3. **Pose Correctness Assessment**: Evaluate form quality using learned patterns from correct examples
# 4. **Real-time Testing**: Test on images, videos, and live webcam feed

# %% [markdown]
# ## 0. Install Required Libraries
#
# Run this cell first to install all necessary packages.

# %%
# %pip install --upgrade opencv-python tensorflow tensorflow-hub numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: opencv-python in c:\workplace\.conda\lib\site-packages (4.13.0.90)
# Requirement already satisfied: tensorflow in c:\workplace\.conda\lib\site-packages (2.20.0)
# Requirement already satisfied: tensorflow-hub in c:\workplace\.conda\lib\site-packages (0.16.1)
# Requirement already satisfied: numpy in c:\workplace\.conda\lib\site-packages (2.4.1)
# Requirement already satisfied: matplotlib in c:\workplace\.conda\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in c:\workplace\.conda\lib\site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\workplace\.conda\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\workplace\.conda\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\workplace\.conda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\workplace\.conda\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\workplace\.conda\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\workplace\.conda\lib\site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\workplace\.conda\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\workplace\.conda\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\workplace\.conda\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\workplace\.conda\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\workplace\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\workplace\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\workplace\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\workplace\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\workplace\.conda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: pillow in c:\workplace\.conda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\workplace\.conda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\workplace\.conda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\workplace\.conda\lib\site-packages (from tensorflow-hub) (2.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\workplace\.conda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\workplace\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\workplace\.conda\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\workplace\.conda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\workplace\.conda\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\workplace\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in c:\workplace\.conda\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\workplace\.conda\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\workplace\.conda\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\workplace\.conda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\workplace\.conda\lib\site-packages (from keras>=3.10.0->tensorflow) (14.3.1)
# Requirement already satisfied: namex in c:\workplace\.conda\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\workplace\.conda\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\workplace\.conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\workplace\.conda\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\workplace\.conda\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\workplace\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the path specified.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import cv2
import numpy as np
import json
import os
from pathlib import Path
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Deep Learning Libraries
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

print("TensorFlow version:", tf.__version__)
print("OpenCV version:", cv2.__version__)
print("TensorFlow Hub available")
print("MoveNet Lightning will be loaded from TensorFlow Hub")
# Out:
# WARNING:tensorflow:From c:\workplace\.conda\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow version: 2.20.0
# OpenCV version: 4.13.0
# TensorFlow Hub available
# MoveNet Lightning will be loaded from TensorFlow Hub

# %% [markdown]
# ## 2. Configure Paths and Parameters

# %%
# Directory Configuration
BASE_DIR = Path(r"C:/Users/Jiesheng He/OneDrive/Documents/aifitnessmirror")
TRAINING_DATA_DIR = BASE_DIR / "data/videos"  # Should contain subfolders: pushups, situps, etc.
OUTPUT_DIR = BASE_DIR / "output"
VISUALIZATION_DIR = OUTPUT_DIR / "visualizations"
MODELS_DIR = OUTPUT_DIR / "models"
JSON_OUTPUT_PATH = OUTPUT_DIR / "all_keypoints.json"

# Create output directories
OUTPUT_DIR.mkdir(exist_ok=True)
VISUALIZATION_DIR.mkdir(exist_ok=True)
MODELS_DIR.mkdir(exist_ok=True)

# MoveNet Configuration
POSE_CONFIDENCE = 0.3  # Minimum detection confidence for keypoints

# Model Configuration
SEQUENCE_LENGTH = 30  # Number of frames to consider for video sequences
NUM_KEYPOINTS = 17  # MoveNet provides 17 keypoints (COCO format)
KEYPOINT_FEATURES = 3  # x, y, confidence per keypoint
INPUT_SHAPE = NUM_KEYPOINTS * KEYPOINT_FEATURES  # Flattened keypoints (17 * 3 = 51)

# Load MoveNet Lightning model from TensorFlow Hub
print("Loading MoveNet Lightning model...")
movenet_model = hub.load('https://tfhub.dev/google/movenet/singlepose/lightning/4')
movenet = movenet_model.signatures['serving_default']

# MoveNet keypoint indices (COCO format)
KEYPOINT_NAMES = [
    'nose', 'left_eye', 'right_eye', 'left_ear', 'right_ear',
    'left_shoulder', 'right_shoulder', 'left_elbow', 'right_elbow',
    'left_wrist', 'right_wrist', 'left_hip', 'right_hip',
    'left_knee', 'right_knee', 'left_ankle', 'right_ankle'
]

print(f"Configuration complete!")
print(f"Training data directory: {TRAINING_DATA_DIR}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Visualizations will be saved to: {VISUALIZATION_DIR}")
print(f"MoveNet Lightning model loaded successfully!")
print(f"Using {NUM_KEYPOINTS} keypoints with {KEYPOINT_FEATURES} features each = {INPUT_SHAPE} total features")
# Out:
# Loading MoveNet Lightning model...
# WARNING:tensorflow:From c:\workplace\.conda\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\workplace\.conda\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\workplace\.conda\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\workplace\.conda\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# Configuration complete!
# Training data directory: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\data\videos
# Output directory: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output
# Visualizations will be saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\visualizations
# MoveNet Lightning model loaded successfully!
# Using 17 keypoints with 3 features each = 51 total features

# %% [markdown]
# ## 3. Load and Process Training Data

# %%
def load_training_data(data_dir):
    """
    Load images and videos from class-labeled folders
    Expected structure: training_data/pushups/, training_data/situps/, etc.
    Returns: dictionary with activity labels and file paths
    """
    data = {
        'images': {},
        'videos': {},
        'classes': []
    }

    if not data_dir.exists():
        print(f"Warning: Training data directory not found: {data_dir}")
        print(f"Please create the directory and add subfolders for each activity class.")
        print(f"Example structure:")
        print(f"  {data_dir}/")
        print(f"    pushups/")
        print(f"      image1.jpg, video1.mp4, ...")
        print(f"    situps/")
        print(f"      image1.jpg, video1.mp4, ...")
        return data

    # Supported file extensions
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp'}
    video_extensions = {'.mp4', '.avi', '.mov', '.mkv'}

    # Scan each class folder
    for class_folder in data_dir.iterdir():
        if class_folder.is_dir():
            class_name = class_folder.name
            data['classes'].append(class_name)
            data['images'][class_name] = []
            data['videos'][class_name] = []

            # Scan files in class folder
            for file_path in class_folder.iterdir():
                if file_path.suffix.lower() in image_extensions:
                    data['images'][class_name].append(file_path)
                elif file_path.suffix.lower() in video_extensions:
                    data['videos'][class_name].append(file_path)

            print(f"Class '{class_name}': {len(data['images'][class_name])} images, {len(data['videos'][class_name])} videos")

    return data

# Load training data
training_data = load_training_data(TRAINING_DATA_DIR)
print(f"\nTotal classes found: {len(training_data['classes'])}")
print(f"Classes: {training_data['classes']}")
# Out:
# Class 'hip thrusts': 0 images, 49 videos
# Class 'jumping jacks': 0 images, 50 videos
# Class 'lunges': 0 images, 55 videos
# Class 'pullups': 0 images, 50 videos
# Class 'pushups': 0 images, 58 videos
# Class 'squats': 0 images, 58 videos
#
# Total classes found: 6
# Classes: ['hip thrusts', 'jumping jacks', 'lunges', 'pullups', 'pushups', 'squats']

# %% [markdown]
# ## 4. Extract Pose Keypoints from Images

# %%
def extract_keypoints_from_image(image_path, movenet_model):
    """
    Extract pose keypoints from a single image using MoveNet Lightning
    Returns: keypoints array (17 landmarks x 3 features) or None if no pose detected
    """
    image = cv2.imread(str(image_path))
    if image is None:
        print(f"Failed to load image: {image_path}")
        return None, None

    # Resize and preprocess for MoveNet (192x192 for Lightning)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    input_image = tf.image.resize_with_pad(tf.expand_dims(tf.convert_to_tensor(image_rgb), 0), 192, 192)
    input_image = tf.cast(input_image, dtype=tf.int32)

    # Run inference
    outputs = movenet_model(input_image)
    keypoints_with_scores = outputs['output_0'].numpy()[0, 0, :, :]

    # Check if pose is detected (using average confidence)
    avg_confidence = np.mean(keypoints_with_scores[:, 2])
    if avg_confidence < POSE_CONFIDENCE:
        return None, image

    # Flatten keypoints: [y, x, confidence] for each of 17 landmarks -> convert to [x, y, confidence]
    keypoints = []
    for i in range(NUM_KEYPOINTS):
        y, x, conf = keypoints_with_scores[i]
        keypoints.extend([x, y, conf])  # Swap to x, y order

    return np.array(keypoints), image

def process_images(image_dict, class_name):
    """
    Process all images for a given class and extract keypoints
    """
    keypoints_data = []

    for img_path in image_dict[class_name]:
        keypoints, image = extract_keypoints_from_image(img_path, movenet)

        if keypoints is not None:
            keypoints_data.append({
                'file': str(img_path),
                'class': class_name,
                'type': 'image',
                'keypoints': keypoints.tolist(),
                'image': image
            })

    print(f"Extracted keypoints from {len(keypoints_data)}/{len(image_dict[class_name])} images for class '{class_name}'")
    return keypoints_data

# Process all image classes
all_image_keypoints = []
for class_name in training_data['classes']:
    if class_name in training_data['images'] and len(training_data['images'][class_name]) > 0:
        class_keypoints = process_images(training_data['images'], class_name)
        all_image_keypoints.extend(class_keypoints)

print(f"\nTotal images processed: {len(all_image_keypoints)}")
# Out:
# Total images processed: 0

# %% [markdown]
# ## 5. Extract Pose Keypoints from Videos

# %%
def extract_keypoints_from_video(video_path, movenet_model, sample_rate=5):
    """
    Extract pose keypoints from video frames using MoveNet Lightning
    sample_rate: process every Nth frame to reduce computation
    Returns: list of keypoint arrays and corresponding frames
    """
    cap = cv2.VideoCapture(str(video_path))
    if not cap.isOpened():
        print(f"Failed to load video: {video_path}")
        return [], []

    keypoints_sequence = []
    frames = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Sample frames to reduce processing time
        if frame_count % sample_rate == 0:
            # Preprocess for MoveNet
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            input_image = tf.image.resize_with_pad(tf.expand_dims(tf.convert_to_tensor(frame_rgb), 0), 192, 192)
            input_image = tf.cast(input_image, dtype=tf.int32)

            # Run inference
            outputs = movenet_model(input_image)
            keypoints_with_scores = outputs['output_0'].numpy()[0, 0, :, :]

            # Check if pose is detected
            avg_confidence = np.mean(keypoints_with_scores[:, 2])
            if avg_confidence >= POSE_CONFIDENCE:
                # Flatten keypoints: convert [y, x, confidence] to [x, y, confidence]
                keypoints = []
                for i in range(NUM_KEYPOINTS):
                    y, x, conf = keypoints_with_scores[i]
                    keypoints.extend([x, y, conf])

                keypoints_sequence.append(np.array(keypoints))
                frames.append(frame)

        frame_count += 1

    cap.release()
    return keypoints_sequence, frames

def process_videos(video_dict, class_name):
    """
    Process all videos for a given class and extract keypoint sequences
    """
    video_keypoints_data = []

    for vid_path in video_dict[class_name]:
        keypoints_seq, frames = extract_keypoints_from_video(vid_path, movenet)

        if len(keypoints_seq) > 0:
            video_keypoints_data.append({
                'file': str(vid_path),
                'class': class_name,
                'type': 'video',
                'keypoints_sequence': [kp.tolist() for kp in keypoints_seq],
                'frames': frames,
                'num_frames': len(keypoints_seq)
            })

    print(f"Extracted keypoints from {len(video_keypoints_data)}/{len(video_dict[class_name])} videos for class '{class_name}'")
    return video_keypoints_data

# Process all video classes
all_video_keypoints = []
for class_name in training_data['classes']:
    if class_name in training_data['videos'] and len(training_data['videos'][class_name]) > 0:
        class_keypoints = process_videos(training_data['videos'], class_name)
        all_video_keypoints.extend(class_keypoints)

print(f"\nTotal videos processed: {len(all_video_keypoints)}")
# Out:
# Extracted keypoints from 48/49 videos for class 'hip thrusts'
# Extracted keypoints from 50/50 videos for class 'jumping jacks'
# Extracted keypoints from 55/55 videos for class 'lunges'
# Extracted keypoints from 50/50 videos for class 'pullups'
# Extracted keypoints from 58/58 videos for class 'pushups'
# Extracted keypoints from 57/58 videos for class 'squats'
#
# Total videos processed: 318

# %% [markdown]
# ## 6. Visualize Skeletal Models on Images

# %%
def draw_pose_on_image(image, keypoints):
    """
    Draw skeletal pose overlay on image using MoveNet keypoints (17 keypoints, COCO format)
    """
    annotated_image = image.copy()
    h, w, _ = image.shape

    # Convert flat keypoints to landmark format (x, y, confidence)
    landmarks = []
    for i in range(0, len(keypoints), 3):
        x, y, conf = keypoints[i:i+3]
        landmarks.append((int(x * w), int(y * h), conf))

    # Define COCO pose connections (17 keypoints)
    # Format: (start_keypoint_index, end_keypoint_index)
    connections = [
        (0, 1), (0, 2), (1, 3), (2, 4),  # Face
        (0, 5), (0, 6),  # Face to shoulders
        (5, 7), (7, 9),  # Left arm
        (6, 8), (8, 10),  # Right arm
        (5, 6),  # Shoulders
        (5, 11), (6, 12),  # Shoulders to hips
        (11, 12),  # Hips
        (11, 13), (13, 15),  # Left leg
        (12, 14), (14, 16)  # Right leg
    ]

    # Draw connections
    for connection in connections:
        start_idx, end_idx = connection
        if start_idx < len(landmarks) and end_idx < len(landmarks):
            start_point = landmarks[start_idx][:2]
            end_point = landmarks[end_idx][:2]
            if landmarks[start_idx][2] > 0.3 and landmarks[end_idx][2] > 0.3:  # Check confidence
                cv2.line(annotated_image, start_point, end_point, (0, 255, 0), 2)

    # Draw keypoints
    for i, (x, y, conf) in enumerate(landmarks):
        if conf > 0.3:
            cv2.circle(annotated_image, (x, y), 5, (0, 0, 255), -1)

    return annotated_image

def save_image_visualizations(image_keypoints_data):
    """
    Save skeletal overlays for all processed images
    """
    img_viz_dir = VISUALIZATION_DIR / "images"
    img_viz_dir.mkdir(exist_ok=True)

    for i, data in enumerate(image_keypoints_data):
        annotated_image = draw_pose_on_image(data['image'], data['keypoints'])

        # Create output filename
        original_name = Path(data['file']).stem
        output_name = f"{data['class']}_{original_name}_pose.jpg"
        output_path = img_viz_dir / output_name

        cv2.imwrite(str(output_path), annotated_image)

    print(f"Saved {len(image_keypoints_data)} image visualizations to {img_viz_dir}")

# Generate and save image visualizations
if len(all_image_keypoints) > 0:
    save_image_visualizations(all_image_keypoints)
    print("Image visualizations complete!")

# %% [markdown]
# ## 7. Visualize Skeletal Models on Videos

# %%
def save_video_visualizations(video_keypoints_data):
    """
    Create and save videos with skeletal overlays
    """
    vid_viz_dir = VISUALIZATION_DIR / "videos"
    vid_viz_dir.mkdir(exist_ok=True)

    for data in video_keypoints_data:
        if len(data['frames']) == 0:
            continue

        # Get video properties
        sample_frame = data['frames'][0]
        h, w, _ = sample_frame.shape

        # Create output filename
        original_name = Path(data['file']).stem
        output_name = f"{data['class']}_{original_name}_pose.mp4"
        output_path = vid_viz_dir / output_name

        # Create video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        fps = 6  # Reduced FPS since we sampled frames
        out = cv2.VideoWriter(str(output_path), fourcc, fps, (w, h))

        # Process each frame
        for frame, keypoints in zip(data['frames'], data['keypoints_sequence']):
            annotated_frame = draw_pose_on_image(frame, keypoints)
            out.write(annotated_frame)

        out.release()

    print(f"Saved {len(video_keypoints_data)} video visualizations to {vid_viz_dir}")

# Generate and save video visualizations
if len(all_video_keypoints) > 0:
    save_video_visualizations(all_video_keypoints)
    print("Video visualizations complete!")
# Out:
# Saved 318 video visualizations to C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\visualizations\videos
# Video visualizations complete!

# %% [markdown]
# ## 8. Save Keypoints to JSON

# %%
def save_keypoints_to_json(image_data, video_data, output_path):
    """
    Compile all keypoints into a single JSON file following COCO-like format
    """
    json_data = {
        'info': {
            'description': 'AI Fitness Mirror - Pose Keypoints Dataset',
            'version': '1.0',
            'date_created': datetime.now().isoformat(),
            'num_keypoints': NUM_KEYPOINTS,
            'keypoint_format': 'MediaPipe Pose (33 landmarks with x, y, z, visibility)'
        },
        'classes': training_data['classes'],
        'images': [],
        'videos': []
    }

    # Add image data
    for i, data in enumerate(image_data):
        json_data['images'].append({
            'id': i,
            'file_path': data['file'],
            'class': data['class'],
            'keypoints': data['keypoints']
        })

    # Add video data
    for i, data in enumerate(video_data):
        # Remove frames from JSON (too large), keep only keypoints
        json_data['videos'].append({
            'id': i,
            'file_path': data['file'],
            'class': data['class'],
            'num_frames': data['num_frames'],
            'keypoints_sequence': data['keypoints_sequence']
        })

    # Save to file
    with open(output_path, 'w') as f:
        json.dump(json_data, f, indent=2)

    print(f"Saved keypoints data to {output_path}")
    print(f"  - Images: {len(json_data['images'])}")
    print(f"  - Videos: {len(json_data['videos'])}")
    print(f"  - Total classes: {len(json_data['classes'])}")

# Save all keypoints to JSON
save_keypoints_to_json(all_image_keypoints, all_video_keypoints, JSON_OUTPUT_PATH)
print("\nJSON file ready for manual verification!")
# Out:
# Saved keypoints data to C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\all_keypoints.json
#   - Images: 0
#   - Videos: 318
#   - Total classes: 6
#
# JSON file ready for manual verification!

# %% [markdown]
# ## 9. Prepare Dataset for Training

# %%
def prepare_training_data(image_data, video_data):
    """
    Convert keypoints to normalized feature vectors for training
    """
    X = []  # Features (keypoints)
    y = []  # Labels (activity classes)

    # Process images
    for data in image_data:
        X.append(data['keypoints'])
        y.append(data['class'])

    # Process videos - extract individual frames
    for data in video_data:
        for keypoints in data['keypoints_sequence']:
            X.append(keypoints)
            y.append(data['class'])

    X = np.array(X)

    # Encode labels
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    y_categorical = to_categorical(y_encoded)

    print(f"Dataset prepared:")
    print(f"  - Total samples: {len(X)}")
    print(f"  - Feature shape: {X.shape}")
    print(f"  - Classes: {label_encoder.classes_}")
    print(f"  - Class distribution: {dict(zip(*np.unique(y, return_counts=True)))}")

    return X, y_categorical, label_encoder

# Prepare data
if len(all_image_keypoints) > 0 or len(all_video_keypoints) > 0:
    X_data, y_data, label_encoder = prepare_training_data(all_image_keypoints, all_video_keypoints)

    # Split into train and validation sets
    X_train, X_val, y_train, y_val = train_test_split(
        X_data, y_data, test_size=0.2, random_state=42, stratify=np.argmax(y_data, axis=1)
    )

    print(f"\nTraining set: {len(X_train)} samples")
    print(f"Validation set: {len(X_val)} samples")

    # Store for later use
    num_classes = len(label_encoder.classes_)
else:
    print("No training data available. Please add images/videos to the training_data folder.")
# Out:
# Dataset prepared:
#   - Total samples: 8506
#   - Feature shape: (8506, 51)
#   - Classes: ['hip thrusts' 'jumping jacks' 'lunges' 'pullups' 'pushups' 'squats']
#   - Class distribution: {np.str_('hip thrusts'): np.int64(1330), np.str_('jumping jacks'): np.int64(1066), np.str_('lunges'): np.int64(1239), np.str_('pullups'): np.int64(1290), np.str_('pushups'): np.int64(1944), np.str_('squats'): np.int64(1637)}
#
# Training set: 6804 samples
# Validation set: 1702 samples

# %% [markdown]
# ## 10. Build Lightweight DNN Model for Activity Classification

# %%
def build_activity_classifier(input_shape, num_classes):
    """
    Build a lightweight DNN for activity classification from pose keypoints
    Uses a simple feedforward network - very efficient for inference
    """
    model = models.Sequential([
        layers.Input(shape=(input_shape,)),

        # Dense layers with dropout for regularization
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.3),
        layers.BatchNormalization(),

        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.BatchNormalization(),

        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),

        # Output layer
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Build the model
if 'num_classes' in locals():
    activity_model = build_activity_classifier(INPUT_SHAPE, num_classes)
    activity_model.summary()

    print(f"\nActivity classification model created!")
    print(f"Input: {INPUT_SHAPE} features (33 landmarks × 4 values)")
    print(f"Output: {num_classes} activity classes")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │        13,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,390 (220.27 KB)
#  Trainable params: 55,622 (217.27 KB)
#  Non-trainable params: 768 (3.00 KB)
# Activity classification model created!
# Input: 51 features (33 landmarks × 4 values)
# Output: 6 activity classes

# %% [markdown]
# ## 11. Build Pose Correctness Assessment Model

# %%
def build_correctness_autoencoder(input_shape, num_classes):
    """
    Build an autoencoder-based correctness model for each activity class
    The model learns to reconstruct correct poses. Reconstruction error indicates incorrectness.
    Low error = correct form, High error = incorrect form

    We create a shared encoder/decoder with class-specific branches
    """
    # Input layer
    input_layer = layers.Input(shape=(input_shape,))
    class_input = layers.Input(shape=(num_classes,))  # One-hot encoded class

    # Concatenate keypoints with class information
    combined = layers.Concatenate()([input_layer, class_input])

    # Encoder
    encoded = layers.Dense(128, activation='relu')(combined)
    encoded = layers.Dropout(0.2)(encoded)
    encoded = layers.Dense(64, activation='relu')(encoded)
    encoded = layers.Dropout(0.2)(encoded)
    encoded = layers.Dense(32, activation='relu')(encoded)  # Bottleneck

    # Decoder
    decoded = layers.Dense(64, activation='relu')(encoded)
    decoded = layers.Dropout(0.2)(decoded)
    decoded = layers.Dense(128, activation='relu')(decoded)
    decoded = layers.Dropout(0.2)(decoded)

    # Reconstruct only the keypoints (not the class)
    output_layer = layers.Dense(input_shape, activation='linear')(decoded)

    # Build model
    model = models.Model(inputs=[input_layer, class_input], outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss='mse',  # Mean squared error for reconstruction
        metrics=['mae']
    )

    return model

# Build correctness model
if 'num_classes' in locals():
    correctness_model = build_correctness_autoencoder(INPUT_SHAPE, num_classes)
    correctness_model.summary()

    print(f"\nCorrectness assessment model created!")
    print(f"This model learns the patterns of CORRECT poses.")
    print(f"Higher reconstruction error = less correct form")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 51)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 57)        │          0 │ input_layer_1[0]… │
# │ (Concatenate)       │                   │            │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │      7,424 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 32)        │      2,080 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      2,112 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │      8,320 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 51)        │      6,579 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 34,771 (135.82 KB)
#  Trainable params: 34,771 (135.82 KB)
#  Non-trainable params: 0 (0.00 B)
# Correctness assessment model created!
# This model learns the patterns of CORRECT poses.
# Higher reconstruction error = less correct form

# %% [markdown]
# ## 12. Train Activity Classification Model

# %%
# Train the activity classification model
if 'activity_model' in locals() and 'X_train' in locals():
    print("Training activity classification model...")

    # Callbacks for better training
    early_stop = keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True
    )

    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7
    )

    # Train
    history = activity_model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=32,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    # Evaluate
    train_loss, train_acc = activity_model.evaluate(X_train, y_train, verbose=0)
    val_loss, val_acc = activity_model.evaluate(X_val, y_val, verbose=0)

    print(f"\n{'='*50}")
    print(f"Activity Classification Model Results:")
    print(f"  Training Accuracy: {train_acc*100:.2f}%")
    print(f"  Validation Accuracy: {val_acc*100:.2f}%")
    print(f"{'='*50}")

    # Plot training history
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Activity Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Activity Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()
else:
    print("Skipping training - no data available")
# Out:
# Training activity classification model...
# Epoch 1/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5004 - loss: 1.2490 - val_accuracy: 0.5828 - val_loss: 1.3102 - learning_rate: 0.0010
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6521 - loss: 0.8704 - val_accuracy: 0.7115 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6786 - loss: 0.7976 - val_accuracy: 0.7009 - val_loss: 0.6740 - learning_rate: 0.0010
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6855 - loss: 0.7812 - val_accuracy: 0.6398 - val_loss: 0.8654 - learning_rate: 0.0010
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7019 - loss: 0.7438 - val_accuracy: 0.7350 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7072 - loss: 0.7324 - val_accuracy: 0.7673 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6993 - loss: 0.7388 - val_accuracy: 0.7662 - val_loss: 0.5700 - learning_rate: 0.0010
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7175 - loss: 0.7206 - val_accuracy: 0.6827 - val_loss: 0.7488 - learning_rate: 0.0010
# Epoch 9/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7163 - loss: 0.7058 - val_accuracy: 0.8073 - val_loss: 0.5025 - learning_rate: 0.0010
# Epoch 10/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7338 - loss: 0.6787 - val_accuracy: 0.7738 - val_loss: 0.5537 - learning_rate: 0.0010
# Epoch 11/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7268 - loss: 0.6649 - val_accuracy: 0.7967 - val_loss: 0.4948 - learning_rate: 0.0010
# Epoch 12/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7497 - loss: 0.6197 - val_accuracy: 0.8143 - val_loss: 0.4282 - learning_rate: 0.0010
# Epoch 13/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.6258 - val_accuracy: 0.8090 - val_loss: 0.4689 - learning_rate: 0.0010
# Epoch 14/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7485 - loss: 0.6309 - val_accuracy: 0.7991 - val_loss: 0.4658 - learning_rate: 0.0010
# Epoch 15/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.6134 - val_accuracy: 0.8120 - val_loss: 0.4574 - learning_rate: 0.0010
# Epoch 16/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.6288 - val_accuracy: 0.8067 - val_loss: 0.4570 - learning_rate: 0.0010
# Epoch 17/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7466 - loss: 0.6261 - val_accuracy: 0.7961 - val_loss: 0.4732 - learning_rate: 0.0010
# Epoch 18/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7769 - loss: 0.5656 - val_accuracy: 0.8255 - val_loss: 0.4162 - learning_rate: 5.0000e-04
# Epoch 19/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.5543 - val_accuracy: 0.8443 - val_loss: 0.3870 - learning_rate: 5.0000e-04
# Epoch 20/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7844 - loss: 0.5560 - val_accuracy: 0.8490 - val_loss: 0.3891 - learning_rate: 5.0000e-04
# Epoch 21/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7907 - loss: 0.5364 - val_accuracy: 0.8543 - val_loss: 0.3663 - learning_rate: 5.0000e-04
# Epoch 22/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7894 - loss: 0.5390 - val_accuracy: 0.8461 - val_loss: 0.3837 - learning_rate: 5.0000e-04
# Epoch 23/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7976 - loss: 0.5127 - val_accuracy: 0.8525 - val_loss: 0.3692 - learning_rate: 5.0000e-04
# Epoch 24/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8042 - loss: 0.5094 - val_accuracy: 0.8525 - val_loss: 0.3724 - learning_rate: 5.0000e-04
# Epoch 25/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7986 - loss: 0.5188 - val_accuracy: 0.8384 - val_loss: 0.3756 - learning_rate: 5.0000e-04
# Epoch 26/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7913 - loss: 0.5245 - val_accuracy: 0.8284 - val_loss: 0.3890 - learning_rate: 5.0000e-04
# Epoch 27/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8086 - loss: 0.4813 - val_accuracy: 0.8590 - val_loss: 0.3429 - learning_rate: 2.5000e-04
# Epoch 28/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4812 - val_accuracy: 0.8596 - val_loss: 0.3476 - learning_rate: 2.5000e-04
# Epoch 29/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8095 - loss: 0.4822 - val_accuracy: 0.8643 - val_loss: 0.3398 - learning_rate: 2.5000e-04
# Epoch 30/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8161 - loss: 0.4743 - val_accuracy: 0.8702 - val_loss: 0.3287 - learning_rate: 2.5000e-04
# Epoch 31/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8236 - loss: 0.4578 - val_accuracy: 0.8807 - val_loss: 0.3135 - learning_rate: 2.5000e-04
# Epoch 32/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.4725 - val_accuracy: 0.8637 - val_loss: 0.3393 - learning_rate: 2.5000e-04
# Epoch 33/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8225 - loss: 0.4591 - val_accuracy: 0.8743 - val_loss: 0.3105 - learning_rate: 2.5000e-04
# Epoch 34/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8285 - loss: 0.4401 - val_accuracy: 0.8737 - val_loss: 0.3219 - learning_rate: 2.5000e-04
# Epoch 35/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8228 - loss: 0.4587 - val_accuracy: 0.8754 - val_loss: 0.3148 - learning_rate: 2.5000e-04
# Epoch 36/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8238 - loss: 0.4520 - val_accuracy: 0.8860 - val_loss: 0.3081 - learning_rate: 2.5000e-04
# Epoch 37/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8300 - loss: 0.4367 - val_accuracy: 0.8772 - val_loss: 0.3042 - learning_rate: 2.5000e-04
# Epoch 38/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8230 - loss: 0.4648 - val_accuracy: 0.8831 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 39/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.4362 - val_accuracy: 0.8766 - val_loss: 0.3153 - learning_rate: 2.5000e-04
# Epoch 40/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8292 - loss: 0.4339 - val_accuracy: 0.8837 - val_loss: 0.2950 - learning_rate: 2.5000e-04
# Epoch 41/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8297 - loss: 0.4350 - val_accuracy: 0.8913 - val_loss: 0.2959 - learning_rate: 2.5000e-04
# Epoch 42/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.4337 - val_accuracy: 0.8843 - val_loss: 0.2992 - learning_rate: 2.5000e-04
# Epoch 43/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8391 - loss: 0.4213 - val_accuracy: 0.8866 - val_loss: 0.2931 - learning_rate: 2.5000e-04
# Epoch 44/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8363 - loss: 0.4286 - val_accuracy: 0.8848 - val_loss: 0.2864 - learning_rate: 2.5000e-04
# Epoch 45/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8348 - loss: 0.4328 - val_accuracy: 0.8860 - val_loss: 0.2918 - learning_rate: 2.5000e-04
# Epoch 46/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.4197 - val_accuracy: 0.8890 - val_loss: 0.2956 - learning_rate: 2.5000e-04
# Epoch 47/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8298 - loss: 0.4399 - val_accuracy: 0.8942 - val_loss: 0.2797 - learning_rate: 2.5000e-04
# Epoch 48/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8345 - loss: 0.4283 - val_accuracy: 0.8790 - val_loss: 0.2980 - learning_rate: 2.5000e-04
# Epoch 49/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8367 - loss: 0.4232 - val_accuracy: 0.8672 - val_loss: 0.3123 - learning_rate: 2.5000e-04
# Epoch 50/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.4046 - val_accuracy: 0.8796 - val_loss: 0.2854 - learning_rate: 2.5000e-04
# Epoch 51/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.4183 - val_accuracy: 0.8931 - val_loss: 0.2773 - learning_rate: 2.5000e-04
# Epoch 52/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8395 - loss: 0.4135 - val_accuracy: 0.8960 - val_loss: 0.2709 - learning_rate: 2.5000e-04
# Epoch 53/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8385 - loss: 0.4114 - val_accuracy: 0.8966 - val_loss: 0.2713 - learning_rate: 2.5000e-04
# Epoch 54/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8369 - loss: 0.4200 - val_accuracy: 0.8925 - val_loss: 0.2748 - learning_rate: 2.5000e-04
# Epoch 55/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8423 - loss: 0.4091 - val_accuracy: 0.8954 - val_loss: 0.2781 - learning_rate: 2.5000e-04
# Epoch 56/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8504 - loss: 0.3988 - val_accuracy: 0.8966 - val_loss: 0.2579 - learning_rate: 2.5000e-04
# Epoch 57/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.4037 - val_accuracy: 0.8925 - val_loss: 0.2768 - learning_rate: 2.5000e-04
# Epoch 58/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8492 - loss: 0.3999 - val_accuracy: 0.8954 - val_loss: 0.2575 - learning_rate: 2.5000e-04
# Epoch 59/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.3931 - val_accuracy: 0.8919 - val_loss: 0.2773 - learning_rate: 2.5000e-04
# Epoch 60/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8466 - loss: 0.4011 - val_accuracy: 0.8878 - val_loss: 0.2775 - learning_rate: 2.5000e-04
# Epoch 61/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8504 - loss: 0.3905 - val_accuracy: 0.9042 - val_loss: 0.2608 - learning_rate: 2.5000e-04
# Epoch 62/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8544 - loss: 0.3895 - val_accuracy: 0.9001 - val_loss: 0.2601 - learning_rate: 2.5000e-04
# Epoch 63/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8499 - loss: 0.4000 - val_accuracy: 0.9083 - val_loss: 0.2463 - learning_rate: 2.5000e-04
# Epoch 64/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3914 - val_accuracy: 0.8931 - val_loss: 0.2704 - learning_rate: 2.5000e-04
# Epoch 65/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8516 - loss: 0.3975 - val_accuracy: 0.8978 - val_loss: 0.2757 - learning_rate: 2.5000e-04
# Epoch 66/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8533 - loss: 0.3849 - val_accuracy: 0.8831 - val_loss: 0.2803 - learning_rate: 2.5000e-04
# Epoch 67/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.3972 - val_accuracy: 0.8984 - val_loss: 0.2633 - learning_rate: 2.5000e-04
# Epoch 68/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8532 - loss: 0.3864 - val_accuracy: 0.9013 - val_loss: 0.2502 - learning_rate: 2.5000e-04
# Epoch 69/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3761 - val_accuracy: 0.9060 - val_loss: 0.2460 - learning_rate: 1.2500e-04
# Epoch 70/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8613 - loss: 0.3654 - val_accuracy: 0.8972 - val_loss: 0.2518 - learning_rate: 1.2500e-04
# Epoch 71/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8591 - loss: 0.3737 - val_accuracy: 0.9048 - val_loss: 0.2412 - learning_rate: 1.2500e-04
# Epoch 72/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8610 - loss: 0.3743 - val_accuracy: 0.9031 - val_loss: 0.2421 - learning_rate: 1.2500e-04
# Epoch 73/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8558 - loss: 0.3822 - val_accuracy: 0.9089 - val_loss: 0.2388 - learning_rate: 1.2500e-04
# Epoch 74/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8629 - loss: 0.3634 - val_accuracy: 0.9042 - val_loss: 0.2433 - learning_rate: 1.2500e-04
# Epoch 75/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8549 - loss: 0.3791 - val_accuracy: 0.9013 - val_loss: 0.2465 - learning_rate: 1.2500e-04
# Epoch 76/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8602 - loss: 0.3660 - val_accuracy: 0.9066 - val_loss: 0.2391 - learning_rate: 1.2500e-04
# Epoch 77/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8604 - loss: 0.3721 - val_accuracy: 0.9048 - val_loss: 0.2430 - learning_rate: 1.2500e-04
# Epoch 78/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8568 - loss: 0.3912 - val_accuracy: 0.9048 - val_loss: 0.2409 - learning_rate: 1.2500e-04
# Epoch 79/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.3669 - val_accuracy: 0.9083 - val_loss: 0.2367 - learning_rate: 6.2500e-05
# Epoch 80/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8686 - loss: 0.3529 - val_accuracy: 0.9101 - val_loss: 0.2349 - learning_rate: 6.2500e-05
# Epoch 81/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.3587 - val_accuracy: 0.9036 - val_loss: 0.2419 - learning_rate: 6.2500e-05
# Epoch 82/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3507 - val_accuracy: 0.9083 - val_loss: 0.2328 - learning_rate: 6.2500e-05
# Epoch 83/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8683 - loss: 0.3444 - val_accuracy: 0.9125 - val_loss: 0.2283 - learning_rate: 6.2500e-05
# Epoch 84/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8627 - loss: 0.3545 - val_accuracy: 0.9072 - val_loss: 0.2337 - learning_rate: 6.2500e-05
# Epoch 85/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8624 - loss: 0.3617 - val_accuracy: 0.9107 - val_loss: 0.2311 - learning_rate: 6.2500e-05
# Epoch 86/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3694 - val_accuracy: 0.9072 - val_loss: 0.2300 - learning_rate: 6.2500e-05
# Epoch 87/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3548 - val_accuracy: 0.9119 - val_loss: 0.2267 - learning_rate: 6.2500e-05
# Epoch 88/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8667 - loss: 0.3467 - val_accuracy: 0.9089 - val_loss: 0.2305 - learning_rate: 6.2500e-05
# Epoch 89/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8658 - loss: 0.3484 - val_accuracy: 0.9078 - val_loss: 0.2285 - learning_rate: 6.2500e-05
# Epoch 90/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8688 - loss: 0.3489 - val_accuracy: 0.9101 - val_loss: 0.2289 - learning_rate: 6.2500e-05
# Epoch 91/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8689 - loss: 0.3488 - val_accuracy: 0.9101 - val_loss: 0.2278 - learning_rate: 6.2500e-05
# Epoch 92/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8685 - loss: 0.3511 - val_accuracy: 0.9060 - val_loss: 0.2305 - learning_rate: 6.2500e-05
# Epoch 93/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8652 - loss: 0.3521 - val_accuracy: 0.9148 - val_loss: 0.2229 - learning_rate: 3.1250e-05
# Epoch 94/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.3506 - val_accuracy: 0.9160 - val_loss: 0.2235 - learning_rate: 3.1250e-05
# Epoch 95/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8686 - loss: 0.3527 - val_accuracy: 0.9160 - val_loss: 0.2270 - learning_rate: 3.1250e-05
# Epoch 96/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.3426 - val_accuracy: 0.9136 - val_loss: 0.2231 - learning_rate: 3.1250e-05
# Epoch 97/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8660 - loss: 0.3516 - val_accuracy: 0.9107 - val_loss: 0.2230 - learning_rate: 3.1250e-05
# Epoch 98/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8762 - loss: 0.3409 - val_accuracy: 0.9101 - val_loss: 0.2228 - learning_rate: 3.1250e-05
# Epoch 99/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8724 - loss: 0.3360 - val_accuracy: 0.9113 - val_loss: 0.2236 - learning_rate: 3.1250e-05
# Epoch 100/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8701 - loss: 0.3443 - val_accuracy: 0.9136 - val_loss: 0.2237 - learning_rate: 3.1250e-05
#
# ==================================================
# Activity Classification Model Results:
#   Training Accuracy: 93.96%
#   Validation Accuracy: 91.01%
# ==================================================

# %% [markdown]
# ## 13. Train Pose Correctness Model

# %%
# Train the correctness assessment model
if 'correctness_model' in locals() and 'X_train' in locals():
    print("Training pose correctness model...")
    print("This model learns to reconstruct CORRECT poses (from training data)")
    print("Reconstruction error will be used to assess form quality\n")

    # Callbacks
    early_stop = keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True
    )

    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7
    )

    # Train to reconstruct the input keypoints
    # The target is the same as input (autoencoder)
    history_correctness = correctness_model.fit(
        [X_train, y_train], X_train,  # Input: keypoints + class, Output: keypoints
        validation_data=([X_val, y_val], X_val),
        epochs=100,
        batch_size=32,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    # Evaluate
    train_loss = correctness_model.evaluate([X_train, y_train], X_train, verbose=0)
    val_loss = correctness_model.evaluate([X_val, y_val], X_val, verbose=0)

    print(f"\n{'='*50}")
    print(f"Correctness Assessment Model Results:")
    print(f"  Training MSE: {train_loss[0]:.6f}")
    print(f"  Validation MSE: {val_loss[0]:.6f}")
    print(f"  (Lower MSE = better reconstruction of correct poses)")
    print(f"{'='*50}")

    # Calculate baseline reconstruction errors for each class
    print("\nCalculating baseline reconstruction errors per class...")
    class_reconstruction_errors = {}

    for class_idx in range(num_classes):
        class_name = label_encoder.classes_[class_idx]
        # Get samples for this class
        class_mask = np.argmax(y_val, axis=1) == class_idx
        if np.sum(class_mask) > 0:
            X_class = X_val[class_mask]
            y_class = y_val[class_mask]

            # Predict and calculate MSE
            predictions = correctness_model.predict([X_class, y_class], verbose=0)
            mse_per_sample = np.mean((X_class - predictions) ** 2, axis=1)

            # Store mean and std for this class
            class_reconstruction_errors[class_name] = {
                'mean': np.mean(mse_per_sample),
                'std': np.std(mse_per_sample),
                'threshold': np.mean(mse_per_sample) + 2 * np.std(mse_per_sample)  # 2-sigma threshold
            }

            print(f"  {class_name}: mean={class_reconstruction_errors[class_name]['mean']:.6f}, "
                  f"threshold={class_reconstruction_errors[class_name]['threshold']:.6f}")

    # Plot training history
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history_correctness.history['loss'], label='Train')
    plt.plot(history_correctness.history['val_loss'], label='Validation')
    plt.title('Correctness Model Loss (MSE)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history_correctness.history['mae'], label='Train MAE')
    plt.plot(history_correctness.history['val_mae'], label='Val MAE')
    plt.title('Correctness Model MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()
else:
    print("Skipping training - no data available")
# Out:
# Training pose correctness model...
# This model learns to reconstruct CORRECT poses (from training data)
# Reconstruction error will be used to assess form quality
#
# Epoch 1/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0455 - mae: 0.1607 - val_loss: 0.0199 - val_mae: 0.1105 - learning_rate: 0.0010
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199 - mae: 0.1093 - val_loss: 0.0133 - val_mae: 0.0870 - learning_rate: 0.0010
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0155 - mae: 0.0958 - val_loss: 0.0103 - val_mae: 0.0764 - learning_rate: 0.0010
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - mae: 0.0904 - val_loss: 0.0094 - val_mae: 0.0731 - learning_rate: 0.0010
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mae: 0.0859 - val_loss: 0.0088 - val_mae: 0.0705 - learning_rate: 0.0010
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - mae: 0.0829 - val_loss: 0.0083 - val_mae: 0.0682 - learning_rate: 0.0010
# Epoch 7/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - mae: 0.0805 - val_loss: 0.0075 - val_mae: 0.0648 - learning_rate: 0.0010
# Epoch 8/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0788 - val_loss: 0.0075 - val_mae: 0.0648 - learning_rate: 0.0010
# Epoch 9/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - mae: 0.0767 - val_loss: 0.0068 - val_mae: 0.0611 - learning_rate: 0.0010
# Epoch 10/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mae: 0.0757 - val_loss: 0.0067 - val_mae: 0.0605 - learning_rate: 0.0010
# Epoch 11/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - mae: 0.0746 - val_loss: 0.0067 - val_mae: 0.0604 - learning_rate: 0.0010
# Epoch 12/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0735 - val_loss: 0.0064 - val_mae: 0.0588 - learning_rate: 0.0010
# Epoch 13/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - mae: 0.0724 - val_loss: 0.0064 - val_mae: 0.0586 - learning_rate: 0.0010
# Epoch 14/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - mae: 0.0715 - val_loss: 0.0062 - val_mae: 0.0579 - learning_rate: 0.0010
# Epoch 15/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - mae: 0.0707 - val_loss: 0.0058 - val_mae: 0.0557 - learning_rate: 0.0010
# Epoch 16/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mae: 0.0698 - val_loss: 0.0058 - val_mae: 0.0556 - learning_rate: 0.0010
# Epoch 17/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - mae: 0.0689 - val_loss: 0.0057 - val_mae: 0.0552 - learning_rate: 0.0010
# Epoch 18/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mae: 0.0687 - val_loss: 0.0055 - val_mae: 0.0536 - learning_rate: 0.0010
# Epoch 19/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0057 - val_mae: 0.0549 - learning_rate: 0.0010
# Epoch 20/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mae: 0.0671 - val_loss: 0.0055 - val_mae: 0.0542 - learning_rate: 0.0010
# Epoch 21/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0055 - val_mae: 0.0543 - learning_rate: 0.0010
# Epoch 22/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0051 - val_mae: 0.0515 - learning_rate: 0.0010
# Epoch 23/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mae: 0.0656 - val_loss: 0.0052 - val_mae: 0.0521 - learning_rate: 0.0010
# Epoch 24/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mae: 0.0650 - val_loss: 0.0053 - val_mae: 0.0529 - learning_rate: 0.0010
# Epoch 25/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0647 - val_loss: 0.0051 - val_mae: 0.0517 - learning_rate: 0.0010
# Epoch 26/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0640 - val_loss: 0.0050 - val_mae: 0.0513 - learning_rate: 0.0010
# Epoch 27/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0641 - val_loss: 0.0051 - val_mae: 0.0515 - learning_rate: 0.0010
# Epoch 28/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0625 - val_loss: 0.0048 - val_mae: 0.0498 - learning_rate: 5.0000e-04
# Epoch 29/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0622 - val_loss: 0.0049 - val_mae: 0.0499 - learning_rate: 5.0000e-04
# Epoch 30/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0618 - val_loss: 0.0049 - val_mae: 0.0505 - learning_rate: 5.0000e-04
# Epoch 31/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0618 - val_loss: 0.0047 - val_mae: 0.0491 - learning_rate: 5.0000e-04
# Epoch 32/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0617 - val_loss: 0.0047 - val_mae: 0.0496 - learning_rate: 5.0000e-04
# Epoch 33/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0615 - val_loss: 0.0047 - val_mae: 0.0487 - learning_rate: 5.0000e-04
# Epoch 34/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0615 - val_loss: 0.0047 - val_mae: 0.0488 - learning_rate: 5.0000e-04
# Epoch 35/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0613 - val_loss: 0.0047 - val_mae: 0.0490 - learning_rate: 5.0000e-04
# Epoch 36/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0611 - val_loss: 0.0046 - val_mae: 0.0487 - learning_rate: 5.0000e-04
# Epoch 37/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0609 - val_loss: 0.0046 - val_mae: 0.0486 - learning_rate: 5.0000e-04
# Epoch 38/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0608 - val_loss: 0.0047 - val_mae: 0.0492 - learning_rate: 5.0000e-04
# Epoch 39/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0599 - val_loss: 0.0045 - val_mae: 0.0482 - learning_rate: 2.5000e-04
# Epoch 40/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0602 - val_loss: 0.0046 - val_mae: 0.0487 - learning_rate: 2.5000e-04
# Epoch 41/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0602 - val_loss: 0.0045 - val_mae: 0.0479 - learning_rate: 2.5000e-04
# Epoch 42/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0597 - val_loss: 0.0045 - val_mae: 0.0482 - learning_rate: 2.5000e-04
# Epoch 43/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0598 - val_loss: 0.0045 - val_mae: 0.0480 - learning_rate: 2.5000e-04
# Epoch 44/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0598 - val_loss: 0.0044 - val_mae: 0.0475 - learning_rate: 2.5000e-04
# Epoch 45/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0596 - val_loss: 0.0044 - val_mae: 0.0474 - learning_rate: 1.2500e-04
# Epoch 46/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0596 - val_loss: 0.0044 - val_mae: 0.0474 - learning_rate: 1.2500e-04
# Epoch 47/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0595 - val_loss: 0.0044 - val_mae: 0.0470 - learning_rate: 1.2500e-04
# Epoch 48/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0595 - val_loss: 0.0044 - val_mae: 0.0470 - learning_rate: 1.2500e-04
# Epoch 49/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0593 - val_loss: 0.0044 - val_mae: 0.0470 - learning_rate: 1.2500e-04
# Epoch 50/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0595 - val_loss: 0.0044 - val_mae: 0.0469 - learning_rate: 1.2500e-04
# Epoch 51/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0044 - val_mae: 0.0471 - learning_rate: 6.2500e-05
# Epoch 52/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0044 - val_mae: 0.0472 - learning_rate: 6.2500e-05
# Epoch 53/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0590 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 6.2500e-05
# Epoch 54/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0044 - val_mae: 0.0470 - learning_rate: 6.2500e-05
# Epoch 55/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0590 - val_loss: 0.0043 - val_mae: 0.0467 - learning_rate: 6.2500e-05
# Epoch 56/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 6.2500e-05
# Epoch 57/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0043 - val_mae: 0.0468 - learning_rate: 6.2500e-05
# Epoch 58/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0590 - val_loss: 0.0043 - val_mae: 0.0467 - learning_rate: 6.2500e-05
# Epoch 59/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0590 - val_loss: 0.0043 - val_mae: 0.0467 - learning_rate: 3.1250e-05
# Epoch 60/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0469 - learning_rate: 3.1250e-05
# Epoch 61/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0468 - learning_rate: 3.1250e-05
# Epoch 62/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 3.1250e-05
# Epoch 63/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 3.1250e-05
# Epoch 64/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 1.5625e-05
# Epoch 65/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0586 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 1.5625e-05
# Epoch 66/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0467 - learning_rate: 1.5625e-05
# Epoch 67/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 1.5625e-05
# Epoch 68/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 1.5625e-05
# Epoch 69/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 7.8125e-06
# Epoch 70/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 7.8125e-06
# Epoch 71/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0586 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 7.8125e-06
# Epoch 72/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 7.8125e-06
# Epoch 73/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 7.8125e-06
# Epoch 74/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 3.9063e-06
# Epoch 75/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0466 - learning_rate: 3.9063e-06
# Epoch 76/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 3.9063e-06
# Epoch 77/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 3.9063e-06
# Epoch 78/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 3.9063e-06
# Epoch 79/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 1.9531e-06
# Epoch 80/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0586 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 1.9531e-06
# Epoch 81/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0585 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 1.9531e-06
# Epoch 82/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0586 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 1.9531e-06
# Epoch 83/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 1.9531e-06
# Epoch 84/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 9.7656e-07
# Epoch 85/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0064 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 9.7656e-07
# Epoch 86/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 9.7656e-07
# Epoch 87/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 9.7656e-07
# Epoch 88/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 9.7656e-07
# Epoch 89/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 4.8828e-07
# Epoch 90/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 4.8828e-07
# Epoch 91/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0064 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 4.8828e-07
# Epoch 92/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 4.8828e-07
# Epoch 93/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 4.8828e-07
# Epoch 94/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 2.4414e-07
# Epoch 95/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0589 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 2.4414e-07
# Epoch 96/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 2.4414e-07
# Epoch 97/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0063 - mae: 0.0588 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 2.4414e-07
# Epoch 98/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0063 - mae: 0.0587 - val_loss: 0.0043 - val_mae: 0.0465 - learning_rate: 2.4414e-07
#
# ==================================================
# Correctness Assessment Model Results:
#   Training MSE: 0.004203
#   Validation MSE: 0.004298
#   (Lower MSE = better reconstruction of correct poses)
# ==================================================
#
# Calculating baseline reconstruction errors per class...
#   hip thrusts: mean=0.004395, threshold=0.007879
#   jumping jacks: mean=0.004099, threshold=0.008756
#   lunges: mean=0.004302, threshold=0.007923
#   pullups: mean=0.004841, threshold=0.010164
#   pushups: mean=0.004344, threshold=0.009269
#   squats: mean=0.003862, threshold=0.007851

# %% [markdown]
# ## 14. Save Trained Models

# %%
# Save combined model with keypoint extraction, activity classification, and correctness assessment
if 'activity_model' in locals():
    print("Saving trained models...")
    
    # Save the trainable models separately (MoveNet will be loaded from TF Hub at inference time)
    activity_model_path = MODELS_DIR / "activity_classifier.keras"
    correctness_model_path = MODELS_DIR / "correctness_assessor.keras"
    
    activity_model.save(activity_model_path)
    correctness_model.save(correctness_model_path)
    
    print(f"✓ Activity classifier saved to: {activity_model_path}")
    print(f"✓ Correctness assessor saved to: {correctness_model_path}")
    
    # Create a combined model for TFLite export only
    # (MoveNet from TF Hub cannot be saved in Keras format)
    class CombinedFitnessModel(tf.keras.Model):
        def __init__(self, movenet_model, activity_model, correctness_model, **kwargs):
            super().__init__(**kwargs)
            self.movenet = movenet_model
            self.activity_classifier = activity_model
            self.correctness_assessor = correctness_model
            
        def call(self, inputs):
            # Input is expected to be a batch of images (batch_size, height, width, 3)
            # Resize and preprocess for MoveNet (192x192 for Lightning)
            input_image = tf.image.resize_with_pad(inputs, 192, 192)
            input_image = tf.cast(input_image, dtype=tf.int32)
            
            # Extract keypoints using MoveNet
            outputs = self.movenet(input_image)
            keypoints_with_scores = outputs['output_0'][:, 0, :, :]  # Shape: (batch, 17, 3)
            
            # Flatten and convert [y, x, confidence] to [x, y, confidence]
            batch_size = tf.shape(keypoints_with_scores)[0]
            keypoints_list = []
            for i in range(17):  # NUM_KEYPOINTS
                y = keypoints_with_scores[:, i, 0]
                x = keypoints_with_scores[:, i, 1]
                conf = keypoints_with_scores[:, i, 2]
                keypoints_list.extend([x, y, conf])
            
            # Stack into shape (batch, 51)
            keypoints_flat = tf.stack(keypoints_list, axis=1)
            
            # Get activity predictions
            activity_probs = self.activity_classifier(keypoints_flat)
            
            # Get predicted class (for correctness assessment)
            predicted_class_idx = tf.argmax(activity_probs, axis=1)
            class_one_hot = tf.one_hot(predicted_class_idx, depth=tf.shape(activity_probs)[1])
            
            # Get correctness assessment
            correctness_reconstruction = self.correctness_assessor([keypoints_flat, class_one_hot])
            
            # Calculate reconstruction error (MSE) per sample
            reconstruction_error = tf.reduce_mean(tf.square(keypoints_flat - correctness_reconstruction), axis=1)
            
            return {
                'keypoints': keypoints_flat,
                'activity_probs': activity_probs,
                'predicted_class': predicted_class_idx,
                'reconstruction_error': reconstruction_error
            }
    
    # Create the combined model for TFLite conversion
    print("\nCreating combined model for TFLite export...")
    combined_model = CombinedFitnessModel(movenet, activity_model, correctness_model)
    
    # Build the model with a sample input
    sample_input = tf.zeros((1, 192, 192, 3), dtype=tf.uint8)
    _ = combined_model(sample_input)
    
    # Save metadata
    metadata = {
        'description': 'AI Fitness Mirror - Trained Models',
        'version': '1.0',
        'date_created': datetime.now().isoformat(),
        'classes': label_encoder.classes_.tolist(),
        'num_classes': num_classes,
        'num_keypoints': NUM_KEYPOINTS,
        'keypoint_features': KEYPOINT_FEATURES,
        'input_keypoints_shape': INPUT_SHAPE,
        'class_reconstruction_errors': class_reconstruction_errors if 'class_reconstruction_errors' in locals() else {},
        'models': {
            'activity_classifier': str(activity_model_path.name),
            'correctness_assessor': str(correctness_model_path.name),
            'movenet': 'Load from TF Hub: https://tfhub.dev/google/movenet/singlepose/lightning/4'
        },
        'usage': {
            'load_models': {
                'activity_classifier': 'keras.models.load_model("activity_classifier.keras")',
                'correctness_assessor': 'keras.models.load_model("correctness_assessor.keras")',
                'movenet': 'hub.load("https://tfhub.dev/google/movenet/singlepose/lightning/4").signatures["serving_default"]'
            },
            'input_image': 'RGB image (height, width, 3) - will be resized to 192x192 by MoveNet',
            'keypoints_shape': '(51,) - 17 keypoints × 3 features (x, y, confidence)',
            'activity_classifier_output': 'Class probabilities (num_classes,)',
            'correctness_assessor_input': '[keypoints, class_one_hot]',
            'correctness_assessor_output': 'Reconstructed keypoints - compare MSE for form quality'
        }
    }
    
    metadata_path = MODELS_DIR / "model_metadata.json"
    with open(metadata_path, 'w') as f:
        json.dump(metadata, f, indent=2)
    print(f"✓ Metadata saved to: {metadata_path}")
    
    # Convert combined model to TensorFlow Lite with Flex ops support
    print("\nConverting combined model to TensorFlow Lite...")
    print("Note: Using TensorFlow Flex ops to support MoveNet operations")
    
    # Representative dataset generator for quantization
    def representative_dataset_gen():
        """Generate representative dataset for quantization using actual images"""
        for i in range(min(100, len(X_val))):
            # Create synthetic images (in production, use actual training images)
            dummy_image = tf.random.uniform((1, 192, 192, 3), minval=0, maxval=255, dtype=tf.float32)
            dummy_image = tf.cast(dummy_image, tf.uint8)
            yield [dummy_image]
    
    tflite_models_saved = []
    
    try:
        print("Creating TFLite converter with Flex ops support...")
        
        # Create a concrete function for conversion
        @tf.function(input_signature=[tf.TensorSpec(shape=[1, 192, 192, 3], dtype=tf.uint8)])
        def model_fn(input_image):
            return combined_model(input_image)
        
        # Get the concrete function
        concrete_func = model_fn.get_concrete_function()
        
        # Convert to TFLite with Flex ops support
        converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func], combined_model)
        
        # Enable optimizations
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_dataset_gen
        
        # Enable TFLITE_BUILTINS and SELECT_TF_OPS (Flex ops)
        # This allows TFLite to use TensorFlow ops that aren't natively supported
        converter.target_spec.supported_ops = [
            tf.lite.OpsSet.TFLITE_BUILTINS,  # Standard TFLite ops
            tf.lite.OpsSet.SELECT_TF_OPS     # TensorFlow Flex ops for MoveNet
        ]
        
        # Set input/output types
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.float32
        
        # Allow custom ops if needed
        converter.allow_custom_ops = True
        
        print("Converting to TFLite (this may take a moment)...")
        tflite_model = converter.convert()
        
        # Save combined TFLite model
        tflite_path = MODELS_DIR / "combined_fitness_model.tflite"
        with open(tflite_path, 'wb') as f:
            f.write(tflite_model)
        
        print(f"✓ Combined TFLite model saved to: {tflite_path}")
        print(f"  Model size: {len(tflite_model) / 1024:.2f} KB")
        print(f"  Note: This model requires TensorFlow Lite with Flex delegate support")
        tflite_models_saved.append(str(tflite_path))
        
    except Exception as e:
        print(f"✗ Combined TFLite conversion failed: {e}")
        print("\nTrying alternative conversion with full TF ops support...")
        
        try:
            # Fallback: Full TF ops support
            converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func], combined_model)
            converter.target_spec.supported_ops = [
                tf.lite.OpsSet.TFLITE_BUILTINS,
                tf.lite.OpsSet.SELECT_TF_OPS
            ]
            converter.allow_custom_ops = True
            
            tflite_model = converter.convert()
            tflite_path = MODELS_DIR / "combined_fitness_model.tflite"
            with open(tflite_path, 'wb') as f:
                f.write(tflite_model)
            
            print(f"✓ Combined TFLite model saved to: {tflite_path}")
            print(f"  Model size: {len(tflite_model) / 1024:.2f} KB")
            tflite_models_saved.append(str(tflite_path))
        except Exception as e2:
            print(f"✗ All TFLite conversion attempts failed: {e2}")
    
    # Update metadata with TFLite information
    metadata['tflite_model'] = {
        'filename': 'combined_fitness_model.tflite' if tflite_models_saved else 'Not created',
        'size_kb': f"{len(tflite_model) / 1024:.2f}" if 'tflite_model' in locals() else 'N/A',
        'input': 'RGB image (1, 192, 192, 3) as uint8',
        'outputs': {
            'keypoints': 'Flattened keypoints (1, 51) as float32',
            'activity_probs': 'Activity class probabilities (1, num_classes) as float32',
            'predicted_class': 'Predicted activity class index (1,) as int64',
            'reconstruction_error': 'Form quality MSE (1,) as float32 - lower is better'
        },
        'requirements': 'TensorFlow Lite with Flex delegate support',
        'deployment': {
            'python': 'Use tf.lite.Interpreter with experimental.load_delegate for Flex ops',
            'android': 'Include TensorFlow Lite Flex delegate in your app',
            'ios': 'Include TensorFlow Lite with Select TF Ops',
            'note': 'Flex ops increase model size but enable full TensorFlow op support'
        }
    }
    
    # Resave metadata with TFLite info
    with open(metadata_path, 'w') as f:
        json.dump(metadata, f, indent=2)
    
    print("\n" + "="*60)
    print("✓ All models saved successfully!")
    print("="*60)
    print(f"Keras Models:")
    print(f"  - Activity Classifier: {activity_model_path}")
    print(f"  - Correctness Assessor: {correctness_model_path}")
    print(f"\nCombined TFLite Model:")
    if tflite_models_saved:
        for tflite_model_path in tflite_models_saved:
            print(f"  - {Path(tflite_model_path).name}")
            print(f"    (Includes: MoveNet + Activity Classifier + Correctness Assessor)")
    else:
        print(f"  - Not created (see errors above)")
    print(f"\nMetadata: {metadata_path}")
    print("="*60)
    print("\nIMPORTANT - TFLite Deployment Notes:")
    print("  - This TFLite model uses TensorFlow Flex ops (SELECT_TF_OPS)")
    print("  - Requires TensorFlow Lite with Flex delegate support")
    print("  - Input: RGB image (1, 192, 192, 3) as uint8")
    print("  - Outputs: keypoints, activity_probs, predicted_class, reconstruction_error")
    print("\nSee model_metadata.json for complete deployment instructions.")
else:
    print("No models to save")
# Out:
# Saving trained models...
# ✓ Activity classifier saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\activity_classifier.keras
# ✓ Correctness assessor saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\correctness_assessor.keras
#
# Creating combined model for TFLite export...
# ✓ Metadata saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\model_metadata.json
#
# Converting combined model to TensorFlow Lite...
# Note: Using TensorFlow Flex ops to support MoveNet operations
# Creating TFLite converter with Flex ops support...
# Converting to TFLite (this may take a moment)...
# ✗ Combined TFLite conversion failed: Select TensorFlow op(s), included in the given model, is(are) not supported by this interpreter. Make sure you apply/link the Flex delegate before inference. For the Android, it can be resolved by adding "org.tensorflow:tensorflow-lite-select-tf-ops" dependency. See instructions: https://www.tensorflow.org/lite/guide/ops_selectNode number 0 (FlexResizeBilinear) failed to prepare.
#
# Trying alternative conversion with full TF ops support...
# ✓ Combined TFLite model saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\combined_fitness_model.tflite
#   Model size: 9540.94 KB
#
# ============================================================
# ✓ All models saved successfully!
# ============================================================
# Keras Models:
#   - Activity Classifier: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\activity_classifier.keras
#   - Correctness Assessor: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\correctness_assessor.keras
#
# Combined TFLite Model:
#   - combined_fitness_model.tflite
#     (Includes: MoveNet + Activity Classifier + Correctness Assessor)
#
# Metadata: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\models\model_metadata.json
# ============================================================
#
# IMPORTANT - TFLite Deployment Notes:
#   - This TFLite model uses TensorFlow Flex ops (SELECT_TF_OPS)
#   - Requires TensorFlow Lite with Flex delegate support
#   - Input: RGB image (1, 192, 192, 3) as uint8
#   - Outputs: keypoints, activity_probs, predicted_class, reconstruction_error
#
# See model_metadata.json for complete deployment instructions.

# %% [markdown]
# ## 15. Test on Single Image
#
# Test the trained models on a new image to classify the activity and assess pose correctness.

# %%
def test_on_image(image_path, activity_model, correctness_model, label_encoder, class_errors):
    """
    Test trained models on a single image
    """
    # Extract keypoints using MoveNet
    keypoints, image = extract_keypoints_from_image(image_path, movenet)

    if keypoints is None:
        print("No pose detected in image!")
        return

    # Reshape for prediction
    keypoints_input = keypoints.reshape(1, -1)

    # Predict activity
    activity_probs = activity_model.predict(keypoints_input, verbose=0)[0]
    predicted_class_idx = np.argmax(activity_probs)
    predicted_class = label_encoder.classes_[predicted_class_idx]
    confidence = activity_probs[predicted_class_idx]

    # Assess correctness
    class_one_hot = to_categorical([predicted_class_idx], num_classes=len(label_encoder.classes_))
    reconstructed = correctness_model.predict([keypoints_input, class_one_hot], verbose=0)
    reconstruction_error = np.mean((keypoints_input - reconstructed) ** 2)

    # Calculate correctness score
    if predicted_class in class_errors:
        threshold = class_errors[predicted_class]['threshold']
        correctness_score = max(0, min(100, 100 * (1 - reconstruction_error / threshold)))
    else:
        correctness_score = 50  # Default if no baseline

    # Visualize
    annotated_image = draw_pose_on_image(image, keypoints)

    # Add text annotations
    h, w, _ = annotated_image.shape
    cv2.putText(annotated_image, f"Activity: {predicted_class}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(annotated_image, f"Confidence: {confidence*100:.1f}%", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(annotated_image, f"Form Quality: {correctness_score:.1f}%", (10, 110),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display
    plt.figure(figsize=(12, 8))
    plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(f"Predicted: {predicted_class} | Confidence: {confidence*100:.1f}% | Form: {correctness_score:.1f}%")
    plt.show()

    print(f"\nResults:")
    print(f"  Activity: {predicted_class}")
    print(f"  Confidence: {confidence*100:.1f}%")
    print(f"  Form Quality Score: {correctness_score:.1f}%")
    print(f"  Reconstruction Error: {reconstruction_error:.6f}")

# Example usage (replace with your test image path)
TEST_IMAGE_PATH = BASE_DIR / "test_image.jpg"

if 'activity_model' in locals() and TEST_IMAGE_PATH.exists():
    print(f"Testing on image: {TEST_IMAGE_PATH}")
    test_on_image(TEST_IMAGE_PATH, activity_model, correctness_model,
                  label_encoder, class_reconstruction_errors)
else:
    print(f"To test on an image, place a test image at: {TEST_IMAGE_PATH}")
    print("Or modify TEST_IMAGE_PATH variable to point to your test image")
# Out:
# To test on an image, place a test image at: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\test_image.jpg
# Or modify TEST_IMAGE_PATH variable to point to your test image

# %% [markdown]
# ## 16. Test on Single Video
#
# Process a test video and generate annotated output with activity classification and form assessment.

# %%
def test_on_video(video_path, activity_model, correctness_model, label_encoder, class_errors, output_path=None):
    """
    Test trained models on a video file
    """
    cap = cv2.VideoCapture(str(video_path))
    if not cap.isOpened():
        print(f"Failed to open video: {video_path}")
        return

    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Calculate adaptive text scaling based on video dimensions
    # Base scale on height (assuming 720p as baseline)
    scale_factor = height / 720.0
    font_scale = max(0.4, min(1.2, 0.5 * scale_factor))  # Clamp between 0.4 and 1.2
    font_thickness = max(1, int(2 * scale_factor))

    # Calculate text positions and spacing
    text_x = int(10 * scale_factor)
    text_y_start = int(30 * scale_factor)
    text_spacing = int(35 * scale_factor)

    # Background rectangle dimensions
    bg_width = int(400 * scale_factor)
    bg_height = int(120 * scale_factor)

    # Create output video writer if path provided
    if output_path:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(str(output_path), fourcc, fps, (width, height))

    frame_count = 0
    predictions_log = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Preprocess for MoveNet
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        input_image = tf.image.resize_with_pad(tf.expand_dims(tf.convert_to_tensor(frame_rgb), 0), 192, 192)
        input_image = tf.cast(input_image, dtype=tf.int32)

        # Run inference
        outputs = movenet(input_image)
        keypoints_with_scores = outputs['output_0'].numpy()[0, 0, :, :]

        # Check if pose is detected
        avg_confidence = np.mean(keypoints_with_scores[:, 2])

        if avg_confidence >= POSE_CONFIDENCE:
            # Extract keypoints
            keypoints = []
            for i in range(NUM_KEYPOINTS):
                y, x, conf = keypoints_with_scores[i]
                keypoints.extend([x, y, conf])
            keypoints = np.array(keypoints)

            # Predict activity
            keypoints_input = keypoints.reshape(1, -1)
            activity_probs = activity_model.predict(keypoints_input, verbose=0)[0]
            predicted_class_idx = np.argmax(activity_probs)
            predicted_class = label_encoder.classes_[predicted_class_idx]
            confidence = activity_probs[predicted_class_idx]

            # Assess correctness
            class_one_hot = to_categorical([predicted_class_idx], num_classes=len(label_encoder.classes_))
            reconstructed = correctness_model.predict([keypoints_input, class_one_hot], verbose=0)
            reconstruction_error = np.mean((keypoints_input - reconstructed) ** 2)

            if predicted_class in class_errors:
                threshold = class_errors[predicted_class]['threshold']
                correctness_score = max(0, min(100, 100 * (1 - reconstruction_error / threshold)))
            else:
                correctness_score = 50

            # Draw pose and annotations
            annotated_frame = draw_pose_on_image(frame, keypoints)

            # Add semi-transparent background for better text visibility
            overlay = annotated_frame.copy()
            cv2.rectangle(overlay, (text_x - 5, text_y_start - int(25 * scale_factor)),
                         (text_x + bg_width, text_y_start + bg_height), (0, 0, 0), -1)
            cv2.addWeighted(overlay, 0.6, annotated_frame, 0.4, 0, annotated_frame)

            # Add scaled text annotations
            cv2.putText(annotated_frame, f"Activity: {predicted_class}",
                       (text_x, text_y_start),
                       cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), font_thickness)
            cv2.putText(annotated_frame, f"Confidence: {confidence*100:.1f}%",
                       (text_x, text_y_start + text_spacing),
                       cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), font_thickness)
            cv2.putText(annotated_frame, f"Form: {correctness_score:.1f}%",
                       (text_x, text_y_start + 2 * text_spacing),
                       cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), font_thickness)

            # Log prediction
            predictions_log.append({
                'frame': frame_count,
                'activity': predicted_class,
                'confidence': float(confidence),
                'form_score': float(correctness_score)
            })

            if output_path:
                out.write(annotated_frame)

        frame_count += 1
        if frame_count % 30 == 0:
            print(f"Processed {frame_count} frames...")

    cap.release()
    if output_path:
        out.release()
        print(f"Output video saved to: {output_path}")

    # Print summary
    if predictions_log:
        print(f"\nVideo Analysis Summary:")
        print(f"  Total frames processed: {frame_count}")
        print(f"  Frames with pose detected: {len(predictions_log)}")

        # Most common activity
        activities = [p['activity'] for p in predictions_log]
        most_common = max(set(activities), key=activities.count)
        print(f"  Most common activity: {most_common}")

        # Average form score
        avg_form = np.mean([p['form_score'] for p in predictions_log])
        print(f"  Average form quality: {avg_form:.1f}%")

# Example usage
TEST_VIDEO_PATH = r"C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\test\ezgif-6a50d0e82efce2b3.mp4"
OUTPUT_VIDEO_PATH = OUTPUT_DIR / "test_video_annotated.mp4"

if 'activity_model' in locals() and Path(TEST_VIDEO_PATH).exists():
    print(f"Testing on video: {TEST_VIDEO_PATH}")
    test_on_video(TEST_VIDEO_PATH, activity_model, correctness_model,
                  label_encoder, class_reconstruction_errors, OUTPUT_VIDEO_PATH)
else:
    print(f"To test on a video, place a test video at: {TEST_VIDEO_PATH}")
    print("Or modify TEST_VIDEO_PATH variable to point to your test video")
# Out:
# Testing on video: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\test\ezgif-6a50d0e82efce2b3.mp4
# Processed 30 frames...
# Output video saved to: C:\Users\Jiesheng He\OneDrive\Documents\aifitnessmirror\output\test_video_annotated.mp4
#
# Video Analysis Summary:
#   Total frames processed: 51
#   Frames with pose detected: 51
#   Most common activity: pullups
#   Average form quality: 58.6%

# %% [markdown]
# ## 17. Test on Live Video Feed
#
# Real-time activity recognition and form assessment using webcam feed.

# %%
def test_live_feed(activity_model, correctness_model, label_encoder, class_errors):
    """
    Real-time activity recognition and form assessment using webcam
    Press 'q' to quit
    """
    cap = cv2.VideoCapture(0)  # 0 for default webcam

    if not cap.isOpened():
        print("Error: Could not open webcam")
        return

    print("Starting live feed...")
    print("Press 'q' to quit")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Flip frame for mirror effect
        frame = cv2.flip(frame, 1)

        # Preprocess for MoveNet
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        input_image = tf.image.resize_with_pad(tf.expand_dims(tf.convert_to_tensor(frame_rgb), 0), 192, 192)
        input_image = tf.cast(input_image, dtype=tf.int32)

        # Run inference
        outputs = movenet(input_image)
        keypoints_with_scores = outputs['output_0'].numpy()[0, 0, :, :]

        # Check if pose is detected
        avg_confidence = np.mean(keypoints_with_scores[:, 2])

        if avg_confidence >= POSE_CONFIDENCE:
            # Extract keypoints
            keypoints = []
            for i in range(NUM_KEYPOINTS):
                y, x, conf = keypoints_with_scores[i]
                keypoints.extend([x, y, conf])
            keypoints = np.array(keypoints)

            # Predict activity
            keypoints_input = keypoints.reshape(1, -1)
            activity_probs = activity_model.predict(keypoints_input, verbose=0)[0]
            predicted_class_idx = np.argmax(activity_probs)
            predicted_class = label_encoder.classes_[predicted_class_idx]
            confidence = activity_probs[predicted_class_idx]

            # Assess correctness
            class_one_hot = to_categorical([predicted_class_idx], num_classes=len(label_encoder.classes_))
            reconstructed = correctness_model.predict([keypoints_input, class_one_hot], verbose=0)
            reconstruction_error = np.mean((keypoints_input - reconstructed) ** 2)

            if predicted_class in class_errors:
                threshold = class_errors[predicted_class]['threshold']
                correctness_score = max(0, min(100, 100 * (1 - reconstruction_error / threshold)))
            else:
                correctness_score = 50

            # Draw pose
            annotated_frame = draw_pose_on_image(frame, keypoints)

            # Add larger, more visible text
            h, w, _ = annotated_frame.shape

            # Background rectangles for better text visibility
            cv2.rectangle(annotated_frame, (5, 5), (400, 130), (0, 0, 0), -1)

            # Text overlays
            cv2.putText(annotated_frame, f"Activity: {predicted_class}", (10, 35),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.putText(annotated_frame, f"Confidence: {confidence*100:.1f}%", (10, 70),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

            # Color-coded form quality
            form_color = (0, 255, 0) if correctness_score >= 70 else (0, 165, 255) if correctness_score >= 50 else (0, 0, 255)
            cv2.putText(annotated_frame, f"Form Quality: {correctness_score:.1f}%", (10, 105),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.9, form_color, 2)

            # Show all class probabilities
            y_offset = 160
            cv2.rectangle(annotated_frame, (w - 305, 5), (w - 5, y_offset + len(label_encoder.classes_) * 35), (0, 0, 0), -1)
            cv2.putText(annotated_frame, "Probabilities:", (w - 300, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
            for i, class_name in enumerate(label_encoder.classes_):
                prob = activity_probs[i]
                cv2.putText(annotated_frame, f"{class_name}: {prob*100:.1f}%",
                           (w - 300, y_offset + i * 35),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

            frame = annotated_frame
        else:
            # No pose detected
            cv2.putText(frame, "No pose detected", (10, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        # Display
        cv2.imshow('AI Fitness Mirror - Live Feed (Press Q to quit)', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    print("Live feed stopped")

# Run live feed test
if 'activity_model' in locals():
    print("\n" + "="*60)
    print("Ready to start live video feed test!")
    print("="*60)
    print("\nUncomment the line below to start the webcam feed:")
    print("test_live_feed(activity_model, correctness_model, label_encoder, class_reconstruction_errors)")
    print("\nNote: The webcam window will open. Press 'q' to quit.")

    # Uncomment the next line to run the live feed
    # test_live_feed(activity_model, correctness_model, label_encoder, class_reconstruction_errors)
else:
    print("Models not trained yet. Please train the models first.")

# %% [markdown]
# ## Summary and Next Steps
#
# **What this notebook does:**
# 1. ✅ Extracts pose keypoints from images/videos using **MoveNet Lightning** (17 keypoints, COCO format)
# 2. ✅ Generates skeletal visualizations saved to separate folders
# 3. ✅ Saves all keypoints to a single JSON file for verification
# 4. ✅ Trains a lightweight DNN to classify activities (pushups, situps, etc.)
# 5. ✅ Trains a correctness model that learns from correct examples (no manual labeling needed)
# 6. ✅ Tests on single images, videos, and live webcam feed
#
# **MoveNet Lightning Benefits:**
# - **Lightweight**: ~1.5MB model size (vs 100MB+ MediaPipe)
# - **Fast**: Optimized for mobile and edge devices
# - **Edge-ready**: Can be converted to TFLite INT8 for deployment on Nuvoton M55
# - **Efficient**: 17 keypoints (51 features) vs MediaPipe's 33 keypoints (132 features)
#
# **To get started:**
# 1. Create a `training_data` folder with subfolders for each activity class:
#    ```
#    training_data/
#    ├── pushups/
#    │   ├── image1.jpg
#    │   └── video1.mp4
#    ├── situps/
#    │   ├── image1.jpg
#    │   └── video1.mp4
#    └── squats/
#        └── ...
#    ```
# 2. Run all cells in order
# 3. Check the `output/visualizations` folder for skeletal overlays
# 4. Check `output/all_keypoints.json` for extracted data
# 5. Test the models using the test cells
#
# **Key Features:**
# - **Lightweight**: Uses simple feedforward neural networks for fast inference
# - **No manual labeling for correctness**: The autoencoder learns what correct form looks like
# - **Real-time capable**: Can process live webcam feed
# - **Flexible**: Works with images, videos, and live streams
# - **Edge-deployable**: Models can be quantized to INT8 for embedded deployment
